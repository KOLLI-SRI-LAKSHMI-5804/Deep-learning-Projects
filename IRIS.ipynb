# %% [markdown]
# 1.Collect the data

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Iris.csv')

# %% [markdown]
# 2.Understanding data

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.shape[0]
# Out:
# 150

# %%
df.shape[1]
# Out:
# 6

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe(include="all").T
# Out:
#                count unique          top freq      mean        std  min  \
# Id             150.0    NaN          NaN  NaN      75.5  43.445368  1.0
# SepalLengthCm  150.0    NaN          NaN  NaN  5.843333   0.828066  4.3
# SepalWidthCm   150.0    NaN          NaN  NaN     3.054   0.433594  2.0
# PetalLengthCm  150.0    NaN          NaN  NaN  3.758667    1.76442  1.0
# PetalWidthCm   150.0    NaN          NaN  NaN  1.198667   0.763161  0.1
# Species          150      3  Iris-setosa   50       NaN        NaN  NaN
#
#                  25%   50%     75%    max
# Id             38.25  75.5  112.75  150.0
# SepalLengthCm    5.1   5.8     6.4    7.9
# SepalWidthCm     2.8   3.0     3.3    4.4
# PetalLengthCm    1.6  4.35     5.1    6.9
# PetalWidthCm     0.3   1.3     1.8    2.5
# Species          NaN   NaN     NaN    NaN

# %%
df.describe(include='object').T
# Out:
#         count unique          top freq
# Species   150      3  Iris-setosa   50

# %%
df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.drop(columns='Id', inplace=True)

# %%
df.head(1)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
import numpy as np
sales_data = {"Person": ["Tarak","Deva", "Hari", "Karim", "Vanitha", "Prasanthi", "Mouli", "Deva"],
            "Company" : [ "CompA","CompA", "CompA", "CompB", "CompB", "CompC", "CompC", "CompA"],
             "Sales"  : [   250  ,  250  ,   150  ,   340  ,   np.nan ,   243  ,   350  ,   250],
             "Age"    : [    23  ,  24   ,   25   ,   250  ,  np.nan,   27   ,    24  ,    24] }
sdf = pd.DataFrame(sales_data)
sdf
# Out:
#       Person Company  Sales    Age
# 0      Tarak   CompA  250.0   23.0
# 1       Deva   CompA  250.0   24.0
# 2       Hari   CompA  150.0   25.0
# 3      Karim   CompB  340.0  250.0
# 4    Vanitha   CompB    NaN    NaN
# 5  Prasanthi   CompC  243.0   27.0
# 6      Mouli   CompC  350.0   24.0
# 7       Deva   CompA  250.0   24.0

# %%
sdf.head()
# Out:
#     Person Company  Sales    Age
# 0    Tarak   CompA  250.0   23.0
# 1     Deva   CompA  250.0   24.0
# 2     Hari   CompA  150.0   25.0
# 3    Karim   CompB  340.0  250.0
# 4  Vanitha   CompB    NaN    NaN

# %%
sdf.tail()
# Out:
#       Person Company  Sales    Age
# 3      Karim   CompB  340.0  250.0
# 4    Vanitha   CompB    NaN    NaN
# 5  Prasanthi   CompC  243.0   27.0
# 6      Mouli   CompC  350.0   24.0
# 7       Deva   CompA  250.0   24.0

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Person   8 non-null      object
#  1   Company  8 non-null      object
#  2   Sales    7 non-null      float64
#  3   Age      7 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 384.0+ bytes

# %%
sdf.shape
# Out:
# (8, 4)

# %%
sdf.shape[0]
# Out:
# 8

# %%
sdf.shape[1]
# Out:
# 4

# %%
sdf.describe().T #compare mean and 50%(median)
# Out:
#        count        mean        std    min     25%    50%    75%    max
# Sales    6.0  263.833333  73.485826  150.0  244.75  250.0  317.5  350.0
# Age      6.0   62.166667  92.029162   23.0   24.00   24.5   26.5  250.0

# %%
sdf.describe(include='object').T
# Out:
#         count unique    top freq
# Person      8      7   Deva    2
# Company     8      3  CompA    4

# %%
sdf.describe(include='all').T
# Out:
#         count unique    top freq        mean        std    min    25%    50%  \
# Person      8      7   Deva    2         NaN        NaN    NaN    NaN    NaN
# Company     8      3  CompA    4         NaN        NaN    NaN    NaN    NaN
# Sales     7.0    NaN    NaN  NaN  261.857143  67.286523  150.0  246.5  250.0
# Age       7.0    NaN    NaN  NaN   56.714286  85.240277   23.0   24.0   24.0
#
#            75%    max
# Person     NaN    NaN
# Company    NaN    NaN
# Sales    295.0  350.0
# Age       26.0  250.0

# %%
sdf.duplicated().sum()
# Out:
# 1

# %%
sdf.drop_duplicates(inplace=True)

# %%
sdf
# Out:
#       Person Company  Sales    Age
# 0      Tarak   CompA  250.0   23.0
# 1       Deva   CompA  250.0   24.0
# 2       Hari   CompA  150.0   25.0
# 3      Karim   CompB  340.0  250.0
# 4    Vanitha   CompB    NaN    NaN
# 5  Prasanthi   CompC  243.0   27.0
# 6      Mouli   CompC  350.0   24.0

# %%
sdf.shape #for huge data
# Out:
# (7, 4)

# %%
sdf.isnull()
# Out:
#    Person  Company  Sales    Age
# 0   False    False  False  False
# 1   False    False  False  False
# 2   False    False  False  False
# 3   False    False  False  False
# 4   False    False   True   True
# 5   False    False  False  False
# 6   False    False  False  False

# %%
sdf.isnull().sum()
# Out:
# Person     0
# Company    0
# Sales      1
# Age        1
# dtype: int64

# %%
sdf["Sales"].fillna(sdf['Sales'].mean(),inplace=True)

# %%
sdf['Age'].fillna(sdf['Age'].median(), inplace=True)

# %%
sdf
# Out:
#       Person Company       Sales    Age
# 0      Tarak   CompA  250.000000   23.0
# 1       Deva   CompA  250.000000   24.0
# 2       Hari   CompA  150.000000   25.0
# 3      Karim   CompB  340.000000  250.0
# 4    Vanitha   CompB  263.833333   24.5
# 5  Prasanthi   CompC  243.000000   27.0
# 6      Mouli   CompC  350.000000   24.0

# %%
sdf['Age'].median()
# Out:
# 24.5

# %%
#Handling of outlier
sdf['Age'].replace(250.0, sdf['Age'].median(), inplace=True)

# %%
sdf
# Out:
#       Person Company       Sales   Age
# 0      Tarak   CompA  250.000000  23.0
# 1       Deva   CompA  250.000000  24.0
# 2       Hari   CompA  150.000000  25.0
# 3      Karim   CompB  340.000000  24.5
# 4    Vanitha   CompB  263.833333  24.5
# 5  Prasanthi   CompC  243.000000  27.0
# 6      Mouli   CompC  350.000000  24.0

# %%
#handling missing values
sdf.dropna()
#sdf.dropna(axis='rows')
#sdf.dropna(axis='columns')

# %%
sdf.dropna(axis='rows', how='all')
# Out:
#       Person Company       Sales   Age
# 0      Tarak   CompA  250.000000  23.0
# 1       Deva   CompA  250.000000  24.0
# 2       Hari   CompA  150.000000  25.0
# 3      Karim   CompB  340.000000  24.5
# 4    Vanitha   CompB  263.833333  24.5
# 5  Prasanthi   CompC  243.000000  27.0
# 6      Mouli   CompC  350.000000  24.0

# %%
sdf.groupby('Company')['Sales'].sum().plot.bar();

# %%
sdf.groupby('Person')['Sales'].sum().plot.pie();
